# %%
import pandas as pd
import seaborn as sns
# Out:
# C:\Users\Matheus\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
reacoes = pd.read_csv('./dados/VigiMed_Reacoes.csv', sep=';', encoding='latin-1')
display(reacoes)
# Out:
#        #IDENTIFICACAO_NOTIFICACAO             REACAO_EVTO_ADVERSO_MEDDRA_LLT  \
# 0             BR-ANVISA-300000004                                    Coceira
# 1             BR-ANVISA-300000005                          Edema periorbital
# 2             BR-ANVISA-300000007                          Exantema alérgico
# 3             BR-ANVISA-300000008                                    Flebite
# 4             BR-ANVISA-300000010                                 Parestesia
# ...                           ...                                        ...
# 325516        BR-ANVISA-300131015                                     Vômito
# 325517        BR-ANVISA-300131015                                Hipertensão
# 325518        BR-ANVISA-300131016                            Confusão mental
# 325519        BR-ANVISA-300131016                                 Sonolência
# 325520        BR-ANVISA-300131017  Erro de prescrição da dose do medicamento
#
#                                    PT  \
# ...

# %%
reacoes['REACAO_EVTO_ADVERSO_MEDDRA_LLT'].value_counts()
# Out:
# Cefaleia                         10188
# Febre                             8805
# Náusea                            6247
# Calafrios                         4804
# Coceira                           4717
#                                  ...
# Glicose em jejum comprometida        1
# Pseudopólipo                         1
# Tumor parotídeo                      1
# Assassinato                          1
# Retinopatia serosa central           1
# Name: REACAO_EVTO_ADVERSO_MEDDRA_LLT, Length: 11884, dtype: int64

# %%
reacoes['GRAVIDADE'].value_counts()
# Out:
# Outro efeito clinicamente significativo                                                                                                                                                           57990
# Hospitalização/Prolongamento de hospitalização                                                                                                                                                    17525
# Resultou em óbito                                                                                                                                                                                  5012
# Hospitalização/Prolongamento de hospitalização, Outro efeito clinicamente significativo                                                                                                            4792
# ...

# %%
reacoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325521 entries, 0 to 325520
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   #IDENTIFICACAO_NOTIFICACAO      325521 non-null  object
#  1   REACAO_EVTO_ADVERSO_MEDDRA_LLT  321811 non-null  object
#  2   PT                              321811 non-null  object
#  3   HLT                             321811 non-null  object
#  4   HLGT                            321811 non-null  object
#  5   SOC                             321811 non-null  object
#  6   DATA_INICIO_HORA                188367 non-null  object
#  7   DATA_FINAL_HORA                 84061 non-null   object
#  8   DURACAO                         41111 non-null   object
#  9   GRAVE                           232045 non-null  object
#  10  GRAVIDADE                       101549 non-null  object
#  11  DESFECHO                        253309 non-null  object
# ...

# %%
reacoes['DURACAO'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 325521 entries, 0 to 325520
# Series name: DURACAO
# Non-Null Count  Dtype
# --------------  -----
# 41111 non-null  object
# dtypes: object(1)
# memory usage: 2.5+ MB

# %%
notificacoes = pd.read_csv('./dados/VigiMed_Notificacoes.csv', sep=';', encoding='latin-1')
notificacoes
# Out:
# C:\Users\Matheus\AppData\Local\Temp\ipykernel_8792\4051936179.py:1: DtypeWarning: Columns (14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   notificacoes = pd.read_csv('./dados/VigiMed_Notificacoes.csv', sep=';', encoding='latin-1')
#         #UF                TIPO_ENTRADA_VIGIMED  \
# 0       NaN                   Serviços de Saúde
# 1       NaN  Pacientes e Profissionais de Saúde
# 2       NaN  Pacientes e Profissionais de Saúde
# 3       NaN                   Serviços de Saúde
# 4       NaN  Pacientes e Profissionais de Saúde
# ...     ...                                 ...
# 114448  NaN  Pacientes e Profissionais de Saúde
# 114449  NaN  Pacientes e Profissionais de Saúde
# 114450  NaN  Pacientes e Profissionais de Saúde
# 114451   MG                   Serviços de Saúde
# 114452   SP                   Serviços de Saúde
#
#                                  RECEBIDO_DE IDENTIFICACAO_NOTIFICACAO  \
# ...

# %%
notificacoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114453 entries, 0 to 114452
# Data columns (total 29 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   #UF                               55374 non-null   object
#  1   TIPO_ENTRADA_VIGIMED              114383 non-null  object
#  2   RECEBIDO_DE                       97013 non-null   object
#  3   IDENTIFICACAO_NOTIFICACAO         114453 non-null  object
#  4   DATA_INCLUSAO_SISTEMA             114453 non-null  int64
#  5   DATA_ULTIMA_ATUALIZACAO           114429 non-null  float64
#  6   DATA_NOTIFICACAO                  67748 non-null   float64
#  7   TIPO_NOTIFICACAO                  114453 non-null  object
#  8   NOTIFICACAO_PARENT_CHILD          447 non-null     object
#  9   DATA_NASCIMENTO                   83512 non-null   float64
#  10  IDADE_MOMENTO_REACAO              64510 non-null   object
# ...
